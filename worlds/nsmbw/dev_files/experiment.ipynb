# %%
import os, sys
sys.path.append(r"C:\Users\Anton\Projekt\Programering\AP-development\Archipelago-NewSuperMarioBrosWii\worlds\nsmbw")
from typing import TYPE_CHECKING

# %%
if TYPE_CHECKING:
    from ..NSMBW_client import patcher

# %%
try:
    from NSMBW_client import patcher
except ModuleNotFoundError:
    pass
# Out:
# No conda env active, defaulting to base
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 2
#       1 try:
# ----> 2     from NSMBW_client import patcher
#       3 except ModuleNotFoundError:
#       4     pass
#
# File ~\Projekt\Programering\AP-development\Archipelago-NewSuperMarioBrosWii\worlds\nsmbw\NSMBW_client\patcher.py:17
#      14 import shutil
#      15 import tempfile
# ---> 17 from ..Common import *
#      18 from ..Utils import bytes_to_int
#      20 #RIIVOLUTION_PATH = Utils.get_settings()["NSMBW.options"].riivolution_path
#      21 #RANDO_PATH = RIIVOLUTION_PATH + r"\\NSMBW_AP_RANDO\\"
#
# ImportError: attempted relative import beyond top-level package

# %%
mem_add = MemoryAddresses("E2")
print(hex(mem_add.powerup_state))
# Out:
# 0x8154cce7

# %%
mem_add = MemoryAddresses("P1")
print(hex(mem_add.powerup_state))
# Out:
# 0x8154cce8

# %%
import operator

print(operator.contains({"asdfasdf"}, "adsfhkjl"))
# Out:
# False

# %%
print(1==True)
# Out:
# True

# %%
from rule_builder import rules

_rule = rules.False_()
type(_rule)
# Out:
# type

# %%
from pathlib import Path
from worlds.nsmbw.NSMBW_client import patcher
arc = patcher.ArcFile(Path(r"C:\Users\Anton\AppData\Local\Temp\nsmbw\DATA\files\Stage\Texture\Pa0_jyotyu.arc"))

print(arc.read())
# Out:
# C:\Users\Anton\Projekt\Programering\AP-development\Archipelago-NewSuperMarioBrosWii\NetUtils.py:536: UserWarning: _speedups not available. Falling back to pure python LocationStore. Install a matching C++ compiler for your platform to compile _speedups.
#   warnings.warn("_speedups not available. Falling back to pure python LocationStore. "
# WARNING:root:excluding name_test from world sources because it has no __init__.py
# WARNING:root:excluding other from world sources because it has no __init__.py
# WARNING:root:excluding tracker from world sources because it has no __init__.py
# WARNING:root:excluding rummy from world sources because it has no __init__.py
# C:\Users\Anton\Projekt\Programering\AP-development\Archipelago-NewSuperMarioBrosWii\ModuleUpdate.py:78: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources  # noqa: F401
# No conda env active, defaulting to base
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[1], line 5
#       2 from worlds.nsmbw.NSMBW_client import patcher
#       3 arc = patcher.ArcFile(Path(r"C:\Users\Anton\AppData\Local\Temp\nsmbw\DATA\files\Stage\Texture\Pa0_jyotyu.arc"))
# ----> 5 print(arc.read())
#
# File ~\Projekt\Programering\AP-development\Archipelago-NewSuperMarioBrosWii\worlds\nsmbw\NSMBW_client\patcher.py:35, in ArcFile.read(self)
#      32 self.read_header()
#      34 for i in range(self.header_size):
# ---> 35     self.read_node(i)
#
# File ~\Projekt\Programering\AP-development\Archipelago-NewSuperMarioBrosWii\worlds\nsmbw\NSMBW_client\patcher.py:53, in ArcFile.read_node(self, offset)
#      51     data_offset = f.read(0x20) # File: Offset of begin of data, Directory: Index of the parent directory.
#      52     size = bytes_to_int(f.read(0x20))
# ---> 53     data = f.read(size)
#      54 return data
#
# OverflowError: cannot fit 'int' into an index-sized integer
